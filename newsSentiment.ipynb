# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
# Out:
# /usr/local/lib/python3.6/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
stop_words = set(stopwords.words('english'))

# %%
file = open('hindu.txt', 'r')
text = file.read()
sentences = text.split('$')
sentences = [w.strip('\n') for w in sentences]
print(sentences)
# Out:
# ['Watch: view from above as the fifth and final shutter of the Cheruthoni dam in Idukki opens.', 'Even a calamity is an opportunity for the business-minded, as was proved by some along the submerged Aluva Manappuram in Kerala. #AluvaManappuram #keralarains', 'Maharashta Anti-Terrorism Squad arrests three men for allegedly planning disruptive activities in the State.', 'About 2,500 Nagarik Seva Kendras in Assam have begun to issue claim, objection and correction forms for people excluded from the complete draft of the NRC. #Assam', 'By book-ending the last monsoon session, the @BJP4India floor managers did a creditable job of steering the ruling coalition through what might otherwise have been a difficult 17 sittings, writes @g_smita #sansadwatch', '@NASA wrote on its Twitter page that the launch was "scrubbed" and a second attempt will be made on Sunday morning. #SolarProbe #parkersolarprobe', 'A long curtain blocking the view of the Periyar on either side of the Marthanda Varma Brid
# ...

# %%
positive = 0
negative = 0 
neutral = 0
sid = SentimentIntensityAnalyzer()
for sentence in sentences:
    # print(sentence)
    ss = sid.polarity_scores(sentence)
    for k in sorted(ss):
        print('{0}: {1}, '.format(k, ss[k]), end='')
    print()
    if(ss['compound'] < -0.2):
        negative = negative + 1
    elif(ss['compound'] > 0.2):
        positive = positive + 1
    else:
        neutral = neutral + 1
print("POSITIVE: ", positive)
print("NEGATIVE: ", negative)
print("NEUTRAL: ", neutral)
# Out:
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# compound: 0.4215, neg: 0.0, neu: 0.882, pos: 0.118,
# compound: -0.6369, neg: 0.302, neu: 0.698, pos: 0.0,
# compound: -0.34, neg: 0.085, neu: 0.915, pos: 0.0,
# compound: 0.0772, neg: 0.075, neu: 0.841, pos: 0.084,
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# compound: -0.3818, neg: 0.085, neu: 0.915, pos: 0.0,
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# compound: 0.875, neg: 0.0, neu: 0.688, pos: 0.312,
# compound: 0.0516, neg: 0.16, neu: 0.67, pos: 0.17,
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# compound: 0.5719, neg: 0.0, neu: 0.879, pos: 0.121,
# compound: -0.5859, neg: 0.242, neu: 0.758, pos: 0.0,
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# compound: 0.128, neg: 0.13, neu: 0.71, pos: 0.16,
# compound: 0.0, neg: 0.0, neu: 1.0, pos: 0.0,
# compound: 0.2263, neg: 0.0, neu: 0.909, pos: 0.091,
# compound: 0.431, neg: 0.0, neu: 0.875, pos: 0.125,
# ...

# %%
sent = ['The movie was not bad.', 'The movie was good', 'The movie wasn\'t good']
for se in sent:
    print(se)
    ss = sid.polarity_scores(se)
    for k in sorted(ss):
        print('{0}: {1}, '.format(k, ss[k]), end='')
    print()
# Out:
# The movie was not bad.
# compound: 0.431, neg: 0.0, neu: 0.584, pos: 0.416,
# The movie was good
# compound: 0.4404, neg: 0.0, neu: 0.508, pos: 0.492,
# The movie wasn't good
# compound: -0.3412, neg: 0.445, neu: 0.555, pos: 0.0,

# %%
import matplotlib.pyplot as plt

#To plot
labels = 'Positive', 'Neutral', 'Negative'
fracs = [positive, neutral, negative]
colors = ['green', 'yellow', 'red']
explode = (0.1, 0, 0)

#Plot
plt.title('Hindu')
plt.pie(fracs, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=120)
plt.axis('equal')
plt.show()

# %%
file = open('timesofindia.txt', 'r')
text = file.read()
sentences = text.split('$')
sentences = [w.strip('\n') for w in sentences]
#print(sentences)

# %%
positive = 0
negative = 0 
neutral = 0
for sentence in sentences:
    # print(sentence)
    ss = sid.polarity_scores(sentence)
    '''for k in sorted(ss):
        print('{0}: {1}, '.format(k, ss[k]), end='')
    print()'''
    if(ss['compound'] < -0.2):
        negative = negative + 1
    elif(ss['compound'] > 0.2):
        positive = positive + 1
    else:
        neutral = neutral + 1
print("POSITIVE: ", positive)
print("NEGATIVE: ", negative)
print("NEUTRAL: ", neutral)
# Out:
# POSITIVE:  135
# NEGATIVE:  151
# NEUTRAL:  241

# %%
import matplotlib.pyplot as plt

#To plot
labels = 'Positive', 'Neutral', 'Negative'
fracs = [positive, neutral, negative]
colors = ['green', 'yellow', 'red']
explode = (0.1, 0, 0)

#Plot
plt.title('Times of India')
plt.pie(fracs, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=120)
plt.axis('equal')
plt.show()

# %%
file = open('nytimes.txt', 'r')
text = file.read()
sentences = text.split('$')
sentences = [w.strip('\n') for w in sentences]
print(sentences)
# Out:
# ["Five days after Bill Clinton's impeachment, Brett Kavanaugh urged the independent counsel pursue a criminal indictment of the president until after he left office https://nyti.ms/2Mi5vdy ", 'Many elderly patients never quite recover from a hospital visit. Why?', "After serving in Iraq, where he went on more than 200 combat missions, Nico Walker became an opioid addict and serial bank robber. Now he's written an unsettling literary novel that draws on his experience.", 'The Trump administration is planning to suspend examinations of lenders for violations of the Military Lending Act, which was devised to protect military service members and their families from financial fraud', 'Nonfiction: Black, Gay and Becoming Visible', 'An estimated 100,000 people gathered in Bucharest’s Piata Victoriei to express their anger at the Romanian government, with tens of thousands protesting in other cities across the country. Chief among their grievances: corruption.', 'Casey Legler was the first w
# ...

# %%
positive = 0
negative = 0 
neutral = 0
sid = SentimentIntensityAnalyzer()
for sentence in sentences:
    # print(sentence)
    ss = sid.polarity_scores(sentence)
    '''for k in sorted(ss):
        print('{0}: {1}, '.format(k, ss[k]), end='')
    print()'''
    if(ss['compound'] < -0.2):
        negative = negative + 1
    elif(ss['compound'] > 0.2):
        positive = positive + 1
    else:
        neutral = neutral + 1
print("POSITIVE: ", positive)
print("NEGATIVE: ", negative)
print("NEUTRAL: ", neutral)
# Out:
# POSITIVE:  154
# NEGATIVE:  198
# NEUTRAL:  176

# %%
import matplotlib.pyplot as plt

#To plot
labels = 'Positive', 'Neutral', 'Negative'
fracs = [positive, neutral, negative]
colors = ['green', 'yellow', 'red']
explode = (0.1, 0, 0)

#Plot
plt.title('NYTimes')
plt.pie(fracs, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=120)
plt.axis('equal')
plt.show()
